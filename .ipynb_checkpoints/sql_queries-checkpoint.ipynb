# %%
# packages

# sql
import sqlite3

import json

import pandas as pd

import re
import os

# to unpack images
import shutil

# %%
# unpack images
shutil.unpack_archive(filename =r'C:\Users\Olivier\Documents\Confirmed_fronts.zip', extract_dir = r'C:\Users\Olivier\Documents\GitHub')

# %% [markdown]
#  # Create the database : need to change the CSV and future database paths

# %%
# Connect to SQLite database (replace 'your_database.db' with your database name)
conn = sqlite3.connect('DVM_car.db')

#----------------------------------------------CHANGE THE PATH------------------------------------------------------
# path to the folder containing unpacked csv's
csv_folder = r'C:\Users\Olivier\Desktop\data'
#-------------------------------------------------------------------------------------------------------------------

listed = []

# Get a list of CSV files in the folder
csv_files = [file for file in os.listdir(csv_folder) if file.endswith('.csv')]

# Loop through each CSV file
for csv_file in csv_files:
    
    # Read the CSV into a DataFrame
    csv_path = os.path.join(csv_folder, csv_file)
    df = pd.read_csv(csv_path, low_memory=False)
    
    # Extract table name from the CSV file name
    table_name = os.path.splitext(csv_file)[0]
    df.replace({'\$\$': '**'}, regex=True, inplace=True)
    # Create a table in the database based on DataFrame columns
    df.to_sql(table_name, conn, index=False, if_exists='replace')

# Commit the changes and close the connection
conn.commit()
#conn.close()

# %%
df
datatable = df.replace({'\$\$': '**'}, regex=True)
# Out:
#         Genmodel_ID     Image_ID  \
# 0               2_1    2_1**1**1
# 1               2_1  2_1**10**11
# 2               2_1  2_1**10**16
# 3               2_1  2_1**10**18
# 4               2_1   2_1**10**2
# ...             ...          ...
# 1451779        99_1   99_1**3**7
# 1451780        99_1   99_1**1**0
# 1451781        99_1   99_1**1**3
# 1451782        99_1   99_1**1**4
# 1451783        99_1   99_1**1**5
#
#                                                 Image_name  \
# 0        Abarth**124 Spider**2017**Blue**2_1**1**image_...
# 1        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 2        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 3        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 4        Abarth**124 Spider**2017**Blue**2_1**10**image...
# ...                                                    ...
# 1451779       Zenos**E10**2016**Grey**99_1**3**image_7.jpg
# 1451780        Zenos**E10**2016**Red**99_1**1**image_0.jpg
# 1451781        Zenos**E10**2016**Red**99_1**1**image_3.jpg
# 1451782        Zenos**E10**2016**Red**99_1**1**image_4.jpg
# 1451783        Zenos**E10**2016**Red**99_1**1**image_5.jpg
#
#          Predicted_viewpoint Quality_check
# 0                         45           NaN
# 1                         45           NaN
# 2                          0             N
# 3                        270           NaN
# 4                        180           NaN
# ...                      ...           ...
# 1451779                   90           NaN
# 1451780                  225           NaN
# 1451781                  315           NaN
# 1451782                   45           NaN
# 1451783                  180           NaN
#
# [1451784 rows x 5 columns]

# %% [markdown]
# # Merge datatable to create a single table

# %%
conn = sqlite3.connect(r'C:\Users\Olivier\Documents\GitHub\DVM_car.db')

query = "SELECT * FROM autosWithNames"
df_autosWithNames = pd.read_sql_query(query, conn)

query2 = "SELECT * FROM `Ad_table (extra)`"
df_Ad_table = pd.read_sql_query(query2, conn)

query3 = "SELECT * FROM Image_table"
df_Images = pd.read_sql_query(query3, conn)

# %%
conn

# %%
df_autosWithNames
# Out:
#            brand             model_name model_id  model_year   bodytype
# 0     Land Rover            Range Rover    47_13        2016        SUV
# 1        Renault                 Trafic    75_17        2015  Combi Van
# 2       Vauxhall                  Astra     94_5        2003  Hatchback
# 3     Volkswagen                Touareg    95_28        2013        SUV
# 4           Audi                     A1      7_1        2017  Hatchback
# ...          ...                    ...      ...         ...        ...
# 3334       Lexus                RX 450h    48_24        2012        SUV
# 3335        MINI            Unspecified    54_11        2003     Saloon
# 3336      Toyota           Land Cruiser    92_21        2017        SUV
# 3337        Ford  Grand Tourneo Connect    29_21        2014        MPV
# 3338        Ford                 Mondeo    29_27        2010  Hatchback
#
# [3339 rows x 5 columns]

# %%
df_Ad_table.columns
# Out:
# Index(['Maker', ' Genmodel', ' Genmodel_ID', 'Adv_ID', 'Adv_year', 'Adv_month',
#        'Color', 'Reg_year', 'Bodytype', 'Runned_Miles', 'Engin_size',
#        'Gearbox', 'Fuel_type', 'Price', 'Engine_power', 'Annual_Tax',
#        'Wheelbase', 'Height', 'Width', 'Length', 'Average_mpg', 'Top_speed',
#        'Seat_num', 'Door_num'],
#       dtype='object')

# %%
df_Ad_table['image_link'] = df_Ad_table['Maker']  +'**'+df_Ad_table[' Genmodel'] +'**'+df_Ad_table['Adv_year'].astype(str)+'**'+df_Ad_table['Color']+'**' +df_Ad_table['Adv_ID']

# %%
df_Ad_table['image_link']
# Out:
# 0          Bentley**Arnage**2018**Silver**10_1**1
# 1            Bentley**Arnage**2018**Grey**10_1**2
# 2            Bentley**Arnage**2017**Blue**10_1**3
# 3           Bentley**Arnage**2018**Green**10_1**4
# 4            Bentley**Arnage**2017**Grey**10_1**5
#                            ...
# 268250    Westfield**Sport**2018**Yellow**97_1**1
# 268251    Westfield**Sport**2018**Yellow**97_1**2
# 268252             Zenos**E10**2018**Red**99_1**1
# 268253           Zenos**E10**2018**Green**99_1**2
# 268254            Zenos**E10**2018**Grey**99_1**3
# Name: image_link, Length: 268255, dtype: object

# %%
query3 = "SELECT * FROM Image_table"
df_Images = pd.read_sql_query(query3, conn)

# %%
df_Images['Image_name'].unique()
# Out:
# array(['Abarth**124 Spider**2017**Blue**2_1**1**image_1.jpg',
#        'Abarth**124 Spider**2017**Blue**2_1**10**image_11.jpg',
#        'Abarth**124 Spider**2017**Blue**2_1**10**image_16.jpg', ...,
#        'Zenos**E10**2016**Red**99_1**1**image_3.jpg',
#        'Zenos**E10**2016**Red**99_1**1**image_4.jpg',
#        'Zenos**E10**2016**Red**99_1**1**image_5.jpg'], dtype=object)

# %%
# Drop everything after the last '*'
df_Images['image_link'] = df_Images['Image_name'].str.rsplit('**', n=1).str[0]

# %%
df_Images
# Out:
#         Genmodel_ID     Image_ID  \
# 0               2_1    2_1**1**1
# 1               2_1  2_1**10**11
# 2               2_1  2_1**10**16
# 3               2_1  2_1**10**18
# 4               2_1   2_1**10**2
# ...             ...          ...
# 1451779        99_1   99_1**3**7
# 1451780        99_1   99_1**1**0
# 1451781        99_1   99_1**1**3
# 1451782        99_1   99_1**1**4
# 1451783        99_1   99_1**1**5
#
#                                                 Image_name  \
# 0        Abarth**124 Spider**2017**Blue**2_1**1**image_...
# 1        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 2        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 3        Abarth**124 Spider**2017**Blue**2_1**10**image...
# 4        Abarth**124 Spider**2017**Blue**2_1**10**image...
# ...                                                    ...
# 1451779       Zenos**E10**2016**Grey**99_1**3**image_7.jpg
# 1451780        Zenos**E10**2016**Red**99_1**1**image_0.jpg
# 1451781        Zenos**E10**2016**Red**99_1**1**image_3.jpg
# 1451782        Zenos**E10**2016**Red**99_1**1**image_4.jpg
# 1451783        Zenos**E10**2016**Red**99_1**1**image_5.jpg
#
#          Predicted_viewpoint Quality_check  \
# 0                         45          None
# 1                         45          None
# 2                          0             N
# 3                        270          None
# 4                        180          None
# ...                      ...           ...
# 1451779                   90          None
# 1451780                  225          None
# 1451781                  315          None
# 1451782                   45          None
# 1451783                  180          None
#
#                                       image_link
# 0         Abarth**124 Spider**2017**Blue**2_1**1
# 1        Abarth**124 Spider**2017**Blue**2_1**10
# 2        Abarth**124 Spider**2017**Blue**2_1**10
# 3        Abarth**124 Spider**2017**Blue**2_1**10
# 4        Abarth**124 Spider**2017**Blue**2_1**10
# ...                                          ...
# 1451779          Zenos**E10**2016**Grey**99_1**3
# 1451780           Zenos**E10**2016**Red**99_1**1
# 1451781           Zenos**E10**2016**Red**99_1**1
# 1451782           Zenos**E10**2016**Red**99_1**1
# 1451783           Zenos**E10**2016**Red**99_1**1
#
# [1451784 rows x 6 columns]

# %% [markdown]
# The path to the good folder is 'Confirmed_fronts/Confirmed_fronts/Brand/year'
# Once we got to here, we can load the image, which is called as Brand//Genmodel//Year//Color//Adv_ID//image_id
#
# Adv_ID = Genmodel_ID + a number
#
# Both last elements aren't in the Images table, gonna have to find a solution to process all cars that match all other elements

# %%
merged_df = pd.merge(df_Images, df_Ad_table, on='image_link', how='inner')

# %%
merged_df
# Out:
#       Genmodel_ID       Image_ID  \
# 0             2_1     2_1**13**8
# 1             2_1     2_1**13**9
# 2             2_1      2_1**6**1
# 3             2_1      2_1**6**2
# 4             2_1     2_1**15**1
# ...           ...            ...
# 77911       96_18  96_18**94**11
# 77912       96_18   96_18**94**2
# 77913       96_18   96_18**94**3
# 77914       96_18   96_18**94**4
# 77915       96_18   96_18**94**5
#
#                                               Image_name  Predicted_viewpoint  \
# 0      Abarth**124 Spider**2017**Grey**2_1**13**image...                    0
# 1      Abarth**124 Spider**2017**Grey**2_1**13**image...                    0
# 2      Abarth**124 Spider**2017**Grey**2_1**6**image_...                   90
# 3      Abarth**124 Spider**2017**Grey**2_1**6**image_...                  180
# 4      Abarth**124 Spider**2017**Red**2_1**15**image_...                   90
# ...                                                  ...                  ...
# 77911  Volvo**XC90**2018**White**96_18**94**image_11.jpg                    0
# 77912   Volvo**XC90**2018**White**96_18**94**image_2.jpg                    0
# 77913   Volvo**XC90**2018**White**96_18**94**image_3.jpg                  135
# 77914   Volvo**XC90**2018**White**96_18**94**image_4.jpg                    0
# 77915   Volvo**XC90**2018**White**96_18**94**image_5.jpg                  225
#
#       Quality_check                               image_link   Maker  \
# 0                 P  Abarth**124 Spider**2017**Grey**2_1**13  Abarth
# 1                 P  Abarth**124 Spider**2017**Grey**2_1**13  Abarth
# 2              None   Abarth**124 Spider**2017**Grey**2_1**6  Abarth
# 3              None   Abarth**124 Spider**2017**Grey**2_1**6  Abarth
# 4              None   Abarth**124 Spider**2017**Red**2_1**15  Abarth
# ...             ...                                      ...     ...
# 77911          None      Volvo**XC90**2018**White**96_18**94   Volvo
# 77912          None      Volvo**XC90**2018**White**96_18**94   Volvo
# 77913          None      Volvo**XC90**2018**White**96_18**94   Volvo
# 77914          None      Volvo**XC90**2018**White**96_18**94   Volvo
# 77915          None      Volvo**XC90**2018**White**96_18**94   Volvo
#
#          Genmodel  Genmodel_ID     Adv_ID  ...  Engine_power  Annual_Tax  \
# 0      124 Spider          2_1    2_1**13  ...         170.0         195
# 1      124 Spider          2_1    2_1**13  ...         170.0         195
# 2      124 Spider          2_1     2_1**6  ...         170.0         195
# 3      124 Spider          2_1     2_1**6  ...         170.0         195
# 4      124 Spider          2_1    2_1**15  ...         170.0        140*
# ...           ...          ...        ...  ...           ...         ...
# 77911        XC90        96_18  96_18**94  ...         235.0        140*
# 77912        XC90        96_18  96_18**94  ...         235.0        140*
# 77913        XC90        96_18  96_18**94  ...         235.0        140*
# 77914        XC90        96_18  96_18**94  ...         235.0        140*
# 77915        XC90        96_18  96_18**94  ...         235.0        140*
#
#       Wheelbase  Height   Width  Length Average_mpg Top_speed Seat_num  \
# 0        2310.0  1233.0  1740.0  4045.0    42.8 mpg   142 mph      2.0
# 1        2310.0  1233.0  1740.0  4045.0    42.8 mpg   142 mph      2.0
# 2        2310.0  1233.0  1740.0  4045.0    42.8 mpg   142 mph      2.0
# 3        2310.0  1233.0  1740.0  4045.0    42.8 mpg   142 mph      2.0
# 4        2310.0  1233.0  1740.0  4045.0    42.8 mpg   142 mph      2.0
# ...         ...     ...     ...     ...         ...       ...      ...
# 77911    2984.0  1776.0  2140.0  4950.0    47.3 mpg   137 mph      7.0
# 77912    2984.0  1776.0  2140.0  4950.0    47.3 mpg   137 mph      7.0
# 77913    2984.0  1776.0  2140.0  4950.0    47.3 mpg   137 mph      7.0
# 77914    2984.0  1776.0  2140.0  4950.0    47.3 mpg   137 mph      7.0
# 77915    2984.0  1776.0  2140.0  4950.0    47.3 mpg   137 mph      7.0
#
#        Door_num
# 0           2.0
# 1           2.0
# 2           2.0
# 3           2.0
# 4           2.0
# ...         ...
# 77911       5.0
# 77912       5.0
# 77913       5.0
# 77914       5.0
# 77915       5.0
#
# [77916 rows x 30 columns]

# %%
merged_df.set_index('image_link', inplace=True)

# %%
merged_df.to_json('json_data.json', orient='split')

# %%
merged_df.reset_index(inplace=True)

# %%
data_dict = {}

for index, row in merged_df.iterrows():
    # Extract image_link
    image_link = row['image_link']
    
    # Create a dictionary to hold data for the current image_link
    row_data = {}
    for column in merged_df.columns:
        if column != 'image_link':
            value=row[column]
            # Check if the value is NaN and handle accordingly
            if pd.notnull(row[column]):
                if type(value)==str:
                    value = value.replace('**', '$$')
                else :
                    pass
            else:
                value = None
            row_data[column] = value
            
    
    # Assign the row data to the image_link key in data_dict
    data_dict[image_link] = row_data

# %%
json_string = json.dumps(data_dict, indent=4)

# Save the JSON string to a file
with open('data.json', 'w') as json_file:
    json_file.write(json_string)

# %%
# close the connection to database
conn.close()
